# %%
import pandas as pd

# %%
df = pd.read_csv('CLN_demonstration.csv')
df
# Out:
#          image_id  x1  cc1 cc2     age   sex     x    type_of        a  \
# 0    JPCLN001.IMG   5   15  53    male  1634   692  malignant  l.upper
# 1    JPCLN002.IMG   5   30  78  female  1614  1090     benign  l.upper
# 2    JPCLN003.IMG   5   30  63  female  1303   447  malignant  l.upper
# 3    JPCLN004.IMG   5   14  68  female   606   836     benign  r.upper
# 4    JPCLN005.IMG   5   35  73  female  1438   692  malignant  l.upper
# ..            ...  ..  ...  ..     ...   ...   ...        ...      ...
# 149  JPCLN150.IMG   1   15  51  female  1544  1409  malignant  l.lower
# 150  JPCLN151.IMG   1   14  37  female  1520  1364  malignant  l.lower
# 151  JPCLN152.IMG   1   10  56    male  1323  1438     benign  l.lower
# 152  JPCLN153.IMG   1   10  64    male  1708  1122  malignant  l.lower
# 153  JPCLN154.IMG   1    8  75  female   660   688  malignant  r.upper
#
#               b             c                 d
# 0          lobe   lung cancer               NaN
# ...

# %%
df['image_id'][31]
# Out:
# 'JPCLN032.IMG'

# %%
df['type_of'].unique()
# Out:
# array(['malignant', 'benign'], dtype=object)

# %%
malignant_list = list(df[df['type_of']=='malignant']['image_id'])
malignant_list
# Out:
# ['JPCLN001.IMG',
#  'JPCLN003.IMG',
#  'JPCLN005.IMG',
#  'JPCLN007.IMG',
#  'JPCLN009.IMG',
#  'JPCLN010.IMG',
#  'JPCLN012.IMG',
#  'JPCLN014.IMG',
#  'JPCLN015.IMG',
#  'JPCLN016.IMG',
#  'JPCLN017.IMG',
#  'JPCLN018.IMG',
#  'JPCLN019.IMG',
#  'JPCLN020.IMG',
#  'JPCLN021.IMG',
#  'JPCLN022.IMG',
#  'JPCLN023.IMG',
#  'JPCLN027.IMG',
#  'JPCLN028.IMG',
#  'JPCLN029.IMG',
#  'JPCLN031.IMG',
#  'JPCLN032.IMG',
#  'JPCLN033.IMG',
#  'JPCLN035.IMG',
#  'JPCLN037.IMG',
#  'JPCLN038.IMG',
#  'JPCLN039.IMG',
#  'JPCLN040.IMG',
#  'JPCLN041.IMG',
#  'JPCLN042.IMG',
#  'JPCLN044.IMG',
#  'JPCLN045.IMG',
#  'JPCLN046.IMG',
#  'JPCLN047.IMG',
#  'JPCLN050.IMG',
#  'JPCLN051.IMG',
#  'JPCLN052.IMG',
#  'JPCLN053.IMG',
#  'JPCLN054.IMG',
#  'JPCLN056.IMG',
#  'JPCLN057.IMG',
#  'JPCLN059.IMG',
#  'JPCLN062.IMG',
#  'JPCLN063.IMG',
#  'JPCLN064.IMG',
#  'JPCLN065.IMG',
#  'JPCLN067.IMG',
#  'JPCLN069.IMG',
#  'JPCLN071.IMG',
#  'JPCLN072.IMG',
#  'JPCLN073.IMG',
#  'JPCLN074.IMG',
# ...

# %%
benign_list = list(df[df['type_of']=='benign']['image_id'])
benign_list
# Out:
# ['JPCLN002.IMG',
#  'JPCLN004.IMG',
#  'JPCLN006.IMG',
#  'JPCLN008.IMG',
#  'JPCLN011.IMG',
#  'JPCLN013.IMG',
#  'JPCLN024.IMG',
#  'JPCLN025.IMG',
#  'JPCLN026.IMG',
#  'JPCLN030.IMG',
#  'JPCLN034.IMG',
#  'JPCLN036.IMG',
#  'JPCLN043.IMG',
#  'JPCLN048.IMG',
#  'JPCLN049.IMG',
#  'JPCLN055.IMG',
#  'JPCLN058.IMG',
#  'JPCLN060.IMG',
#  'JPCLN061.IMG',
#  'JPCLN066.IMG',
#  'JPCLN068.IMG',
#  'JPCLN070.IMG',
#  'JPCLN075.IMG',
#  'JPCLN078.IMG',
#  'JPCLN079.IMG',
#  'JPCLN087.IMG',
#  'JPCLN089.IMG',
#  'JPCLN094.IMG',
#  'JPCLN096.IMG',
#  'JPCLN098.IMG',
#  'JPCLN100.IMG',
#  'JPCLN101.IMG',
#  'JPCLN102.IMG',
#  'JPCLN107.IMG',
#  'JPCLN111.IMG',
#  'JPCLN115.IMG',
#  'JPCLN119.IMG',
#  'JPCLN121.IMG',
#  'JPCLN122.IMG',
#  'JPCLN123.IMG',
#  'JPCLN124.IMG',
#  'JPCLN127.IMG',
#  'JPCLN135.IMG',
#  'JPCLN136.IMG',
#  'JPCLN137.IMG',
#  'JPCLN138.IMG',
#  'JPCLN139.IMG',
#  'JPCLN141.IMG',
#  'JPCLN142.IMG',
#  'JPCLN144.IMG',
#  'JPCLN146.IMG',
#  'JPCLN148.IMG',
# ...

# %%
# Out:
# True

# %%
import os,sys
path = '../JSRT/preprocessed/data/Nodule/'
df = pd.read_csv('~/Desktop/uni-study/CS431/final-project/demonstration/CLN_demonstration.csv')
cnt = 0
for i, filename in enumerate(os.listdir(path)):
    print(i)
    if (df[df['image_id'] == filename[:-4] + '.IMG']['type_of'] == 'malignant').bool():
        print('ok1')
#         print(filename[:-4])
#         os.system('mv ~/Desktop/uni-study/CS431/final-project/JSRT/preprocessed/data/Nodule/' + filename + ' ~/Desktop/uni-study/CS431/final-project/JSRT/preprocessed/data/Nodule/Cancer/') 
    if (df[df['image_id'] == filename[:-4] + '.IMG']['type_of'] == 'benign').bool():
        print('ok2')
#          os.system('mv ~/Desktop/uni-study/CS431/final-project/JSRT/preprocessed/data/Nodule/' + filename + ' ~/Desktop/uni-study/CS431/final-project/JSRT/preprocessed/data/Nodule/Benign/')
# Out:
# 0
# ok1
# 1
# ok1
# 2
# ok2
# 3
# ok2
# 4
# ok2
# 5
# ok2
# 6
# ok2
# 7
# ok1
# 8
# ok1
# 9
# ok1
# 10
# ok1
# 11
# ok1
# 12
# ok1
# 13
# ok2
# 14
# ok1
# 15
# ok1
# 16
# ok1
# 17
# ok1
# 18
# ok1
# 19
# ok2
# 20
# ok2
# 21
# ok1
# 22
# ok2
# 23
# ok1
# 24
# ok1
# 25
# ok2
# 26
# ok1
# 27
# ok1
# 28
# ok1
# 29
# ok1
# 30
# ok1
# 31
# ok2
# 32
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-982dcf179ede> in <module>
#       5 for i, filename in enumerate(os.listdir(path)):
#       6     print(i)
# ----> 7     if (df[df['image_id'] == filename[:-4] + '.IMG']['type_of'] == 'malignant').bool():
#       8         print('ok1')
#       9 #         print(filename[:-4])
#
# ~/miniforge3/lib/python3.9/site-packages/pandas/core/generic.py in bool(self)
#    1490             )
#    1491
# -> 1492         self.__nonzero__()
#    1493
#    1494     @final
#
# ...
